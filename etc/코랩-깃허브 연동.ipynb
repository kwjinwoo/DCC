# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 깃허브에서 코드를 가져오기

# %%
cd "/content/drive/MyDrive"
# Out:
# /content/drive/MyDrive

# %%
#Settings -> Developer settings ->
#Personal access tokens -> Generate new token에서 토큰 생성

# !git clone https://아이디:토큰@github.com/kwjinwoo/DCC.git
# Out:
# Cloning into 'DCC'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 139 (delta 37), reused 69 (delta 12), pack-reused 0
# Receiving objects: 100% (139/139), 53.39 MiB | 14.27 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %% [markdown]
# # 커밋하기

# %%
cd "/content/drive/MyDrive/DCC"
# Out:
# /content/drive/MyDrive/DCC

# %%
#수정하기 전 변경된 내역 가져오기
# !git pull
# Out:
# Already up to date.

# %%
#config 설정
# !git config --global user.email "이메일"
# !git config --global user.name "이름"

# %%
# !git add .
# !git status
# !git commit -m "change colab-git file"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	deleted:    "etc/\341\204\217\341\205\251\341\204\205\341\205\242\341\206\270-\341\204\200\341\205\265\341\206\272\341\204\222\341\205\245\341\204\207\341\205\263 \341\204\213\341\205\247\341\206\253\341\204\203\341\205\251\341\206\274"
# 	new file:   "etc/\341\204\217\341\205\251\341\204\205\341\205\242\341\206\270-\341\204\200\341\205\265\341\206\272\341\204\222\341\205\245\341\204\207\341\205\263 \341\204\213\341\205\247\341\206\253\341\204\203\341\205\251\341\206\274.ipynb"
#
# [main 94b26f1] change colab-git file
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  delete mode 100644 "etc/\341\204\217\341\205\251\341\204\205\341\205\242\341\206\270-\341\204\200\341\205\265\341\206\272\341\204\222\341\205\245\341\204\207\341\205\263 \341\204\213\341\205\247\341\206\253\341\204\203\341\205\251\341\206\274"
#  create mode 100644 "etc/\341\204\217\341\205\251\341\204\205\341\205\242\341\206\270-\341\204\200\341\205\265\341\206\272\341\204\222\341\205\245\341\204\207\341\205\263 \341\204\213\341\205\247\341\206\253\341\204\203\341\205\251\341\206\274.ipynb"

# %%
# !git push origin main
# Out:
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 1.59 KiB | 232.00 KiB/s, done.
# Total 8 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/kwjinwoo/DCC.git
#    9e73390..94b26f1  main -> main

# %%
# 커밋이 안될 때? 참고
# !git fetch origin
# !git rebase origin/main
# Out:
# Current branch main is up to date.
