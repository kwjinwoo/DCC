# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pycaret
# !pip install kmodes
# Out:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: yellowbrick
#     Found existing installation: yellowbrick 0.9.1
#     Uninstalling yellowbrick-0.9.1:
#       Successfully uninstalled yellowbrick-0.9.1
#   Attempting uninstall: pandas-profiling
#     Found existing installation: pandas-profiling 1.4.1
#     Uninstalling pandas-profiling-1.4.1:
#       Successfully uninstalled pandas-profiling-1.4.1
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.4.3
#     Uninstalling imbalanced-learn-0.4.3:
#       Successfully uninstalled imbalanced-learn-0.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Boruta-0.3 Mako-1.1.5 PyYAML-5.4.1 alembic-1.4.1 databricks-cli-0.15.0 docker-5.0.2 funcy-1.16 gitdb-4.0.7 gitpython-3.1.24 gunicorn-20.1.0 htmlmin-0.1.12 imagehash-4.2.1 imbalanced-learn-0.7.0 kmodes-0.11.0 lightgbm-3.2.1 mlflow-1.20.2 mlxtend-0.19.0 multimethod-1.4 pandas-profiling-3.0.0 phik-0.12.0 prometheus-flask-exporter-0.18.2 pyLDAvis-3.2.2 pycaret-2.3.3 pydantic-1.8.2 pynndescent-0.5.4 pyod-0.9.3 python-editor-1.0.4 querystring-parser-1.2.4 requests-2.26.0 scikit-learn-0.23.2 scikit-plot-0.3.7 scipy-1.5.4 smmap-4.0.0 tangled-up-in-unicode-0.1.0 threadpoolctl-2.2.0 umap-learn-0.5.1 visions-0.7.1 websocket-client-1.2.1 yellowbrick-1.3.post1
# Requirement already satisfied: kmodes in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from kmodes) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.0.1)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.5.4)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.0->kmodes) (2.2.0)

# %%
import pandas as pd
from pycaret.classification import *
from kmodes.kprototypes import KPrototypes

# %%
train_data = pd.read_csv('/content/drive/MyDrive/DCC/dacon_data/card_data/train.csv', index_col=0)
test_data = pd.read_csv('/content/drive/MyDrive/DCC/dacon_data/card_data/test.csv', index_col=0)
submission = pd.read_csv('/content/drive/MyDrive/DCC/dacon_data/card_data/sample_submission.csv', index_col=0)

# %%
## origin data
train_data
# Out:
#       gender car reality  child_num  income_total           income_type  \
# index
# 0          F   N       N          0      202500.0  Commercial associate
# 1          F   N       Y          1      247500.0  Commercial associate
# 2          M   Y       Y          0      450000.0               Working
# 3          F   N       Y          0      202500.0  Commercial associate
# 4          F   Y       Y          0      157500.0         State servant
# ...      ...  ..     ...        ...           ...                   ...
# 26452      F   N       N          2      225000.0         State servant
# 26453      F   N       Y          1      180000.0               Working
# 26454      F   Y       N          0      292500.0               Working
# 26455      M   N       Y          0      171000.0               Working
# 26456      F   N       N          0       81000.0               Working
#
#                             edu_type           family_type  \
# index
# 0                   Higher education               Married
# 1      Secondary / secondary special        Civil marriage
# 2                   Higher education               Married
# 3      Secondary / secondary special               Married
# 4                   Higher education               Married
# ...                              ...                   ...
# 26452  Secondary / secondary special               Married
# 26453               Higher education             Separated
# 26454  Secondary / secondary special        Civil marriage
# 26455              Incomplete higher  Single / not married
# 26456  Secondary / secondary special        Civil marriage
#
#                 house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  \
# index
# 0      Municipal apartment      -13899          -4709           1           0
# 1        House / apartment      -11380          -1540           1           0
# 2        House / apartment      -19087          -4434           1           0
# 3        House / apartment      -15088          -2092           1           0
# 4        House / apartment      -15037          -2105           1           0
# ...                    ...         ...            ...         ...         ...
# 26452    House / apartment      -12079          -1984           1           0
# 26453    House / apartment      -15291          -2475           1           0
# 26454         With parents      -10082          -2015           1           0
# 26455    House / apartment      -10145           -107           1           0
# 26456    House / apartment      -19569          -1013           1           0
#
#        phone  email      occyp_type  family_size  begin_month  credit
# index
# 0          0      0             NaN          2.0         -6.0     1.0
# 1          0      1        Laborers          3.0         -5.0     1.0
# 2          1      0        Managers          2.0        -22.0     2.0
# 3          1      0     Sales staff          2.0        -37.0     0.0
# 4          0      0        Managers          2.0        -26.0     2.0
# ...      ...    ...             ...          ...          ...     ...
# 26452      0      0      Core staff          4.0         -2.0     1.0
# 26453      0      0             NaN          2.0        -47.0     2.0
# 26454      0      0      Core staff          2.0        -25.0     2.0
# 26455      0      0        Laborers          1.0        -59.0     2.0
# 26456      0      0  Security staff          2.0         -9.0     2.0
#
# [26457 rows x 19 columns]

# %%
# Na -> unknown
train_data.fillna("unknown", inplace=True)

# %%
## 범주형 변수 설정
categorical_features_idx = [0,1,2,5,6,7,8,11,12,13,14,15]

# %%
mark_array=train_data.values

# %%
# k-Modes clustering(categorical data도 cluster 가능)
## 연속형 변수가 아닌 범주형 변수로 클러스터링 가능
## 3 cluster
kproto = KPrototypes(n_clusters=3, verbose=2, max_iter=20).fit(mark_array, categorical=categorical_features_idx)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 1970, ncost: 138565786951721.67
# Run: 1, iteration: 2/20, moves: 950, ncost: 134366872846258.48
# Run: 1, iteration: 3/20, moves: 86, ncost: 134336734405144.3
# Run: 1, iteration: 4/20, moves: 0, ncost: 134336734405144.3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 501, ncost: 138246390794010.23
# Run: 2, iteration: 2/20, moves: 92, ncost: 138229993849722.1
# Run: 2, iteration: 3/20, moves: 0, ncost: 138229993849722.1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 73, ncost: 134336734405144.3
# Run: 3, iteration: 2/20, moves: 0, ncost: 134336734405144.3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 397, ncost: 134337179861118.56
# Run: 4, iteration: 2/20, moves: 10, ncost: 134336734405144.3
# Run: 4, iteration: 3/20, moves: 0, ncost: 134336734405144.3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 715, ncost: 151733357647612.12
# Run: 5, iteration: 2/20, moves: 1097, ncost: 138284567816368.7
# Run: 5, iteration: 3/20, moves: 885, ncost: 134365533369032.55
# Run: 5, iteration: 4/20, moves: 84, ncost: 134336734405144.3
# Run: 5, iteration: 5/20, moves: 0, ncost: 134336734405144.3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 3236, ncost: 140121833501653.36
# Run: 6, iteration: 2/20, moves: 1196, ncost: 138233919095915.33
# Run: 6, iteration: 3/20, moves: 52, ncost: 138229993849722.1
# Run: 6, iteration: 4/20, moves: 0, ncost: 138229993849722.1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 5777, ncost: 269165293636688.38
# Run: 7, iteration: 2/20, moves: 7829, ncost: 167721589613689.47
# Run: 7, iteration: 3/20, moves: 5774, ncost: 140698482145017.66
# Run: 7, iteration: 4/20, moves: 1385, ncost: 138234227747715.97
# Run: 7, iteration: 5/20, moves: 54, ncost: 138229993849722.1
# Run: 7, iteration: 6/20, moves: 0, ncost: 138229993849722.1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 8680, ncost: 152350069452228.8
# Run: 8, iteration: 2/20, moves: 3584, ncost: 139387300333337.33
# Run: 8, iteration: 3/20, moves: 917, ncost: 138230199486005.02
# Run: 8, iteration: 4/20, moves: 12, ncost: 138229993849722.1
# Run: 8, iteration: 5/20, moves: 0, ncost: 138229993849722.1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 689, ncost: 152742059985116.0
# Run: 9, iteration: 2/20, moves: 1092, ncost: 138659225358214.53
# Run: 9, iteration: 3/20, moves: 920, ncost: 134379953942179.75
# Run: 9, iteration: 4/20, moves: 103, ncost: 134336734405144.3
# Run: 9, iteration: 5/20, moves: 0, ncost: 134336734405144.3
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 95, ncost: 134336734405144.3
# Run: 10, iteration: 2/20, moves: 0, ncost: 134336734405144.3
# Best run was number 1

# %%
# cluster centroids
print(kproto.cluster_centroids_)
# Out:
# [['0.47173427020121367' '386970.91887575854' '-15299.843819865857'
#   '-1291.0664324496965' '2.2561481954647076' '-26.68827850526988'
#   '1.5247524752475248' 'F' 'Y' 'Y' 'Working' 'Higher education' 'Married'
#   'House / apartment' '1' '0' '0' '0' 'Managers']
#  ['0.5107666261044389' '163423.82157028728' '-14706.396328236602'
#   '-2612.348976244643' '2.293582350140204' '-26.08327601714195'
#   '1.5202370244960584' 'F' 'N' 'Y' 'Working'
#   'Secondary / secondary special' 'Married' 'House / apartment' '1' '0'
#   '0' '0' 'Laborers']
#  ['0.04745762711864407' '148042.73898305086' '-21770.129717514123'
#   '365243.0' '1.7416949152542374' '-25.89446327683616'
#   '1.5129943502824859' 'F' 'N' 'Y' 'Pensioner'
#   'Secondary / secondary special' 'Married' 'House / apartment' '1' '0'
#   '0' '0' 'unknown']]

# %%
# prediction
clusters = kproto.predict(mark_array, categorical=categorical_features_idx)

# %%
train_data['cluster'] = list(clusters)

# %%
train_data[train_data['cluster']==1].head(10)
# Out:
#       gender car reality  child_num  income_total           income_type  \
# index
# 0          F   N       N          0      202500.0  Commercial associate
# 1          F   N       Y          1      247500.0  Commercial associate
# 3          F   N       Y          0      202500.0  Commercial associate
# 4          F   Y       Y          0      157500.0         State servant
# 5          F   N       Y          2      270000.0               Working
# 7          M   N       Y          0      270000.0  Commercial associate
# 8          M   Y       Y          1      180000.0  Commercial associate
# 9          F   N       Y          0      103500.0               Working
# 10         F   N       Y          0      193500.0               Working
# 11         M   Y       Y          1      135000.0  Commercial associate
#
#                             edu_type     family_type           house_type  \
# index
# 0                   Higher education         Married  Municipal apartment
# 1      Secondary / secondary special  Civil marriage    House / apartment
# 3      Secondary / secondary special         Married    House / apartment
# 4                   Higher education         Married    House / apartment
# 5      Secondary / secondary special         Married    House / apartment
# 7      Secondary / secondary special         Married    House / apartment
# 8                   Higher education         Married    House / apartment
# 9      Secondary / secondary special         Married    House / apartment
# 10     Secondary / secondary special       Separated    House / apartment
# 11                  Higher education         Married    House / apartment
#
#        DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  \
# index
# 0          -13899          -4709           1           0      0      0
# 1          -11380          -1540           1           0      0      1
# 3          -15088          -2092           1           0      1      0
# 4          -15037          -2105           1           0      0      0
# 5          -13413          -4996           1           0      0      1
# 7          -14896          -5420           1           0      0      1
# 8          -15131          -1466           1           0      0      1
# 9          -15785          -1308           1           0      0      0
# 10         -19063          -2213           1           1      1      1
# 11         -11759            -91           1           0      0      0
#
#                   occyp_type  family_size  begin_month  credit  cluster
# index
# 0                    unknown          2.0         -6.0     1.0        1
# 1                   Laborers          3.0         -5.0     1.0        1
# 3                Sales staff          2.0        -37.0     0.0        1
# 4                   Managers          2.0        -26.0     2.0        1
# 5      High skill tech staff          4.0        -18.0     1.0        1
# 7                    Drivers          2.0        -53.0     0.0        1
# 8                    unknown          3.0        -38.0     2.0        1
# 9             Medicine staff          2.0         -5.0     2.0        1
# 10                  Laborers          1.0        -40.0     2.0        1
# 11                  Managers          3.0        -51.0     2.0        1

# %%
## cluster feature add
train_data
# Out:
#       gender car reality  child_num  income_total           income_type  \
# index
# 0          F   N       N          0      202500.0  Commercial associate
# 1          F   N       Y          1      247500.0  Commercial associate
# 2          M   Y       Y          0      450000.0               Working
# 3          F   N       Y          0      202500.0  Commercial associate
# 4          F   Y       Y          0      157500.0         State servant
# ...      ...  ..     ...        ...           ...                   ...
# 26452      F   N       N          2      225000.0         State servant
# 26453      F   N       Y          1      180000.0               Working
# 26454      F   Y       N          0      292500.0               Working
# 26455      M   N       Y          0      171000.0               Working
# 26456      F   N       N          0       81000.0               Working
#
#                             edu_type           family_type  \
# index
# 0                   Higher education               Married
# 1      Secondary / secondary special        Civil marriage
# 2                   Higher education               Married
# 3      Secondary / secondary special               Married
# 4                   Higher education               Married
# ...                              ...                   ...
# 26452  Secondary / secondary special               Married
# 26453               Higher education             Separated
# 26454  Secondary / secondary special        Civil marriage
# 26455              Incomplete higher  Single / not married
# 26456  Secondary / secondary special        Civil marriage
#
#                 house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  \
# index
# 0      Municipal apartment      -13899          -4709           1           0
# 1        House / apartment      -11380          -1540           1           0
# 2        House / apartment      -19087          -4434           1           0
# 3        House / apartment      -15088          -2092           1           0
# 4        House / apartment      -15037          -2105           1           0
# ...                    ...         ...            ...         ...         ...
# 26452    House / apartment      -12079          -1984           1           0
# 26453    House / apartment      -15291          -2475           1           0
# 26454         With parents      -10082          -2015           1           0
# 26455    House / apartment      -10145           -107           1           0
# 26456    House / apartment      -19569          -1013           1           0
#
#        phone  email      occyp_type  family_size  begin_month  credit  cluster
# index
# 0          0      0         unknown          2.0         -6.0     1.0        1
# 1          0      1        Laborers          3.0         -5.0     1.0        1
# 2          1      0        Managers          2.0        -22.0     2.0        0
# 3          1      0     Sales staff          2.0        -37.0     0.0        1
# 4          0      0        Managers          2.0        -26.0     2.0        1
# ...      ...    ...             ...          ...          ...     ...      ...
# 26452      0      0      Core staff          4.0         -2.0     1.0        1
# 26453      0      0         unknown          2.0        -47.0     2.0        1
# 26454      0      0      Core staff          2.0        -25.0     2.0        0
# 26455      0      0        Laborers          1.0        -59.0     2.0        1
# 26456      0      0  Security staff          2.0         -9.0     2.0        1
#
# [26457 rows x 20 columns]

# %%
# pycaret을 이용한 AutoML 환경 설정/ traget=credit
model = setup(train_data, target = 'credit', use_gpu=True)
# Out:
#                                Description             Value
# 0                               session_id              7500
# 1                                   Target            credit
# 2                              Target Type        Multiclass
# 3                            Label Encoded              None
# 4                            Original Data       (26457, 20)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                14
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set       (18519, 62)
# 12                    Transformed Test Set        (7938, 62)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU              True
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              1123
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE

# %%
## 모델 비교(변수 포함, 클러스터 변수 포함)

compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.7003  0.7460  0.5398  0.6790
# lightgbm  Light Gradient Boosting Machine    0.6972  0.6942  0.4243  0.6892
# gbc          Gradient Boosting Classifier    0.6922  0.6530  0.4099  0.6621
# ada                  Ada Boost Classifier    0.6913  0.6239  0.4044  0.6264
# et                 Extra Trees Classifier    0.6693  0.7052  0.5172  0.6486
# nb                            Naive Bayes    0.6446  0.6079  0.3371  0.5737
# lda          Linear Discriminant Analysis    0.6431  0.6075  0.3373  0.5218
# ridge                    Ridge Classifier    0.6429  0.0000  0.3355  0.5359
# lr                    Logistic Regression    0.6420  0.5809  0.3333  0.4122
# knn                K Neighbors Classifier    0.6116  0.6499  0.4497  0.5860
# dt               Decision Tree Classifier    0.6039  0.6366  0.4911  0.6153
# qda       Quadratic Discriminant Analysis    0.5679  0.5004  0.3309  0.4824
# svm                   SVM - Linear Kernel    0.4912  0.0000  0.3329  0.3183
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6837  0.3703  0.3769     4.368
# lightgbm  0.6202  0.2338  0.3163     0.716
# gbc       0.6071  0.2101  0.3005     8.660
# ada       0.6017  0.1991  0.3002     0.872
# et        0.6548  0.3128  0.3171     5.554
# nb        0.5086  0.0119  0.0653     0.046
# lda       0.5099  0.0122  0.0468     0.290
# ridge     0.5061  0.0065  0.0378     0.065
# lr        0.5021  0.0000  0.0000     0.677
# knn       0.5953  0.1950  0.1977     0.804
# dt        0.6091  0.2530  0.2534     0.229
# qda       0.5001 -0.0012 -0.0021     0.150
# svm       0.3702 -0.0006 -0.0020     1.391
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=7500, verbose=0,
#                        warm_start=False)

# %%
# clustering한 feature 제외

# 특정 변수만 포함 (3,4,9,10,16)
train_data2 = train_data[["child_num",	"income_total",  "DAYS_BIRTH",	"DAYS_EMPLOYED","credit", "cluster"]]

# %%
model = setup(train_data2, target = 'credit', use_gpu=True)
# Out:
#                                Description             Value
# 0                               session_id              7580
# 1                                   Target            credit
# 2                              Target Type        Multiclass
# 3                            Label Encoded              None
# 4                            Original Data        (26457, 6)
# 5                           Missing Values             False
# 6                         Numeric Features                 3
# 7                     Categorical Features                 2
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set       (18519, 13)
# 12                    Transformed Test Set        (7938, 13)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU              True
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              f95c
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE

# %%
## 모델 비교 (변수 제거, 클러스터 변수 포함)
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.6561  0.7052  0.5240  0.6408
# lightgbm  Light Gradient Boosting Machine    0.6497  0.6170  0.3598  0.6330
# et                 Extra Trees Classifier    0.6447  0.7074  0.5456  0.6444
# gbc          Gradient Boosting Classifier    0.6443  0.5702  0.3402  0.6270
# lr                    Logistic Regression    0.6418  0.5209  0.3333  0.4119
# ridge                    Ridge Classifier    0.6418  0.0000  0.3334  0.4355
# ada                  Ada Boost Classifier    0.6418  0.5359  0.3341  0.5523
# lda          Linear Discriminant Analysis    0.6418  0.5303  0.3334  0.4355
# nb                            Naive Bayes    0.6411  0.5209  0.3329  0.4118
# dt               Decision Tree Classifier    0.6336  0.6885  0.5447  0.6408
# knn                K Neighbors Classifier    0.6160  0.6560  0.4689  0.5960
# svm                   SVM - Linear Kernel    0.5051  0.0000  0.3334  0.3451
# qda       Quadratic Discriminant Analysis    0.1225  0.0000  0.3333  0.0150
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6463  0.3007  0.3028     3.339
# lightgbm  0.5379  0.0592  0.1214     0.527
# et        0.6444  0.3128  0.3129     3.559
# gbc       0.5115  0.0156  0.0617     4.391
# lr        0.5018  0.0000  0.0000     0.343
# ridge     0.5019  0.0000  0.0013     0.042
# ada       0.5029  0.0017  0.0148     0.567
# lda       0.5019  0.0000  0.0013     0.101
# nb        0.5015 -0.0009 -0.0072     0.032
# dt        0.6368  0.3053  0.3057     0.086
# knn       0.6036  0.2157  0.2176     0.412
# svm       0.3824  0.0003  0.0007     0.629
# qda       0.0267  0.0000  0.0000     0.046
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=7580, verbose=0,
#                        warm_start=False)

# %%
## 클러스터 변수 제외
train_data3 = train_data.loc[:, [col for col in train_data.columns if col != "cluster"]]

# %%
model = setup(train_data3, target = 'credit', use_gpu=True)
# Out:
#                                Description             Value
# 0                               session_id              5854
# 1                                   Target            credit
# 2                              Target Type        Multiclass
# 3                            Label Encoded              None
# 4                            Original Data       (26457, 19)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                13
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set       (18519, 60)
# 12                    Transformed Test Set        (7938, 60)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU              True
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              b61a
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE

# %%
## 모델 비교 (변수 전체, 클러스터 변수 미포함)
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.6993  0.7481  0.5407  0.6780
# lightgbm  Light Gradient Boosting Machine    0.6983  0.7121  0.4315  0.6942
# gbc          Gradient Boosting Classifier    0.6901  0.6571  0.4099  0.6447
# ada                  Ada Boost Classifier    0.6886  0.6304  0.4046  0.6303
# et                 Extra Trees Classifier    0.6693  0.7088  0.5161  0.6476
# lda          Linear Discriminant Analysis    0.6415  0.6099  0.3389  0.5283
# ridge                    Ridge Classifier    0.6411  0.0000  0.3365  0.5430
# nb                            Naive Bayes    0.6405  0.6081  0.3342  0.5640
# lr                    Logistic Regression    0.6398  0.5496  0.3333  0.4094
# knn                K Neighbors Classifier    0.6106  0.6563  0.4622  0.5907
# dt               Decision Tree Classifier    0.6046  0.6361  0.4905  0.6142
# qda       Quadratic Discriminant Analysis    0.5255  0.5011  0.3328  0.4767
# svm                   SVM - Linear Kernel    0.4188  0.0000  0.3329  0.4047
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6828  0.3716  0.3781     4.544
# lightgbm  0.6244  0.2456  0.3251     0.758
# gbc       0.6046  0.2095  0.2987     9.564
# ada       0.5991  0.1981  0.2957     0.937
# et        0.6539  0.3137  0.3184     5.616
# lda       0.5099  0.0165  0.0559     0.284
# ridge     0.5053  0.0096  0.0478     0.070
# nb        0.5009  0.0030  0.0326     0.045
# lr        0.4993  0.0000  0.0000     0.579
# knn       0.5983  0.2085  0.2103     0.632
# dt        0.6089  0.2544  0.2548     0.237
# qda       0.4884  0.0001 -0.0001     0.143
# svm       0.3491  0.0006 -0.0011     1.611
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=5854, verbose=0,
#                        warm_start=False)
