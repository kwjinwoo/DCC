# %%
import pandas as pd
import os
import preprocessing as pr
from pycaret.classification import *

# %%
data_path = '../../../data'

train_path = os.path.join(data_path, '심리/train.csv')
train = pd.read_csv(train_path, index_col=0)

# %%
x_train, y_train, names = pr.make_train_set(train)

# %%
x_train.shape, y_train.shape
# Out:
# ((45532, 93), (45532,))

# %%
train_data = pd.concat([x_train, y_train], axis=1)

# %%
train_data.columns
# Out:
# Index(['QaA', 'QaE', 'QbA', 'QbE', 'QcA', 'QcE', 'QdA', 'QdE', 'QeA', 'QeE',
#        'QfA', 'QfE', 'QgA', 'QgE', 'QhA', 'QhE', 'QiA', 'QiE', 'QjA', 'QjE',
#        'QkA', 'QkE', 'QlA', 'QlE', 'QmA', 'QmE', 'QnA', 'QnE', 'QoA', 'QoE',
#        'QpA', 'QpE', 'QqA', 'QqE', 'QrA', 'QrE', 'QsA', 'QsE', 'QtA', 'QtE',
#        'age_group', 'education', 'engnat', 'familysize', 'gender', 'hand',
#        'married', 'tp01', 'tp02', 'tp03', 'tp04', 'tp05', 'tp06', 'tp07',
#        'tp08', 'tp09', 'tp10', 'urban', 'wf_01', 'wf_02', 'wf_03', 'wr_01',
#        'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06', 'wr_07', 'wr_08', 'wr_09',
#        'wr_10', 'wr_11', 'wr_12', 'wr_13', 'race__Arab', 'race__Asian',
#        'race__Black', 'race__Indigenous Australian', 'race__Native American',
#        'race__Other', 'race__White', 'religion__Agnostic', 'religion__Atheist',
#        'religion__Buddhist', 'religion__Christian_Catholic',
#        'religion__Christian_Mormon', 'religion__Christian_Other',
#        'religion__Christian_Protestant', 'religion__Hindu', 'religion__Jewish',
#        'religion__Muslim', 'religion__Other', 'religion__Sikh', 'voted'],
#       dtype='object')

# %%
clf = setup(train_data, target='voted')
# Out:
# <style type="text/css">
# #T_a88f4_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a88f4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a88f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a88f4_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a88f4_row0_col1" class="data row0 col1" >4235</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a88f4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a88f4_row1_col1" class="data row1 col1" >voted</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a88f4_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_a88f4_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a88f4_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_a88f4_row3_col1" class="data row3 col1" >1: 0, 2: 1</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a88f4_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_a88f4_row4_col1" class="data row4 col1" >(45532, 94)</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a88f4_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_a88f4_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a88f4_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_a88f4_row6_col1" class="data row6 col1" >62</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a88f4_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_a88f4_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a88f4_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_a88f4_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a88f4_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_a88f4_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a88f4_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_a88f4_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a88f4_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_a88f4_row11_col1" class="data row11 col1" >(31872, 177)</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a88f4_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_a88f4_row12_col1" class="data row12 col1" >(13660, 177)</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a88f4_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_a88f4_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a88f4_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_a88f4_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a88f4_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_a88f4_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a88f4_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_a88f4_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a88f4_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_a88f4_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a88f4_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_a88f4_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a88f4_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_a88f4_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a88f4_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_a88f4_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a88f4_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_a88f4_row21_col1" class="data row21 col1" >bc9c</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a88f4_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_a88f4_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a88f4_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_a88f4_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a88f4_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_a88f4_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a88f4_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_a88f4_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a88f4_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_a88f4_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_a88f4_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_a88f4_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_a88f4_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_a88f4_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_a88f4_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_a88f4_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a88f4_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_a88f4_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_a88f4_row30_col1" class="data row30 col1" >None</td>
#     </tr

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_d13f9_ th {
#   text-align: left;
# }
# #T_d13f9_row0_col0, #T_d13f9_row0_col3, #T_d13f9_row0_col5, #T_d13f9_row1_col0, #T_d13f9_row1_col1, #T_d13f9_row1_col2, #T_d13f9_row1_col3, #T_d13f9_row1_col4, #T_d13f9_row1_col5, #T_d13f9_row1_col6, #T_d13f9_row1_col7, #T_d13f9_row2_col0, #T_d13f9_row2_col1, #T_d13f9_row2_col2, #T_d13f9_row2_col3, #T_d13f9_row2_col4, #T_d13f9_row2_col5, #T_d13f9_row2_col6, #T_d13f9_row2_col7, #T_d13f9_row3_col0, #T_d13f9_row3_col1, #T_d13f9_row3_col2, #T_d13f9_row3_col3, #T_d13f9_row3_col4, #T_d13f9_row3_col5, #T_d13f9_row3_col6, #T_d13f9_row3_col7, #T_d13f9_row4_col0, #T_d13f9_row4_col1, #T_d13f9_row4_col2, #T_d13f9_row4_col3, #T_d13f9_row4_col4, #T_d13f9_row4_col5, #T_d13f9_row4_col6, #T_d13f9_row4_col7, #T_d13f9_row5_col0, #T_d13f9_row5_col1, #T_d13f9_row5_col2, #T_d13f9_row5_col3, #T_d13f9_row5_col4, #T_d13f9_row5_col6, #T_d13f9_row5_col7, #T_d13f9_row6_col0, #T_d13f9_row6_col1, #T_d13f9_row6_col2, #T_d13f9_row6_col3, #T_d13f9_row6_col4, #T_d13f9_row6_col5, #T_d13f9_row6_col6, #T_d13f9_row6_col7, #T_d13f9_row7_col0, #T_d13f9_row7_col1, #T_d13f9_row7_col2, #T_d13f9_row7_col3, #T_d13f9_row7_col4, #T_d13f9_row7_col5, #T_d13f9_row7_col6, #T_d13f9_row7_col7, #T_d13f9_row8_col0, #T_d13f9_row8_col1, #T_d13f9_row8_col2, #T_d13f9_row8_col4, #T_d13f9_row8_col5, #T_d13f9_row8_col6, #T_d13f9_row8_col7, #T_d13f9_row9_col0, #T_d13f9_row9_col1, #T_d13f9_row9_col2, #T_d13f9_row9_col3, #T_d13f9_row9_col4, #T_d13f9_row9_col5, #T_d13f9_row9_col6, #T_d13f9_row9_col7, #T_d13f9_row10_col0, #T_d13f9_row10_col1, #T_d13f9_row10_col2, #T_d13f9_row10_col3, #T_d13f9_row10_col4, #T_d13f9_row10_col5, #T_d13f9_row10_col6, #T_d13f9_row10_col7, #T_d13f9_row11_col0, #T_d13f9_row11_col1, #T_d13f9_row11_col2, #T_d13f9_row11_col3, #T_d13f9_row11_col4, #T_d13f9_row11_col5, #T_d13f9_row11_col6, #T_d13f9_row11_col7, #T_d13f9_row12_col0, #T_d13f9_row12_col1, #T_d13f9_row12_col2, #T_d13f9_row12_col3, #T_d13f9_row12_col4, #T_d13f9_row12_col5, #T_d13f9_row12_col6, #T_d13f9_row12_col7 {
#   text-align: left;
# }
# #T_d13f9_row0_col1, #T_d13f9_row0_col2, #T_d13f9_row0_col4, #T_d13f9_row0_col6, #T_d13f9_row0_col7, #T_d13f9_row5_col5, #T_d13f9_row8_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d13f9_row0_col8, #T_d13f9_row1_col8, #T_d13f9_row2_col8, #T_d13f9_row3_col8, #T_d13f9_row4_col8, #T_d13f9_row5_col8, #T_d13f9_row7_col8, #T_d13f9_row8_col8, #T_d13f9_row9_col8, #T_d13f9_row10_col8, #T_d13f9_row11_col8, #T_d13f9_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d13f9_row6_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d13f9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d13f9_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_d13f9_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_d13f9_row0_col1" class="data row0 col1" >0.6939</td>
#       <td id="T_d13f9_row0_col2" class="data row0 col2" >0.7673</td>
#       <td id="T_d13f9_row0_col3" class="data row0 col3" >0.6494</td>
#       <td id="T_d13f9_row0_col4" class="data row0 col4" >0.7586</td>
#       <td id="T_d13f9_row0_col5" class="data row0 col5" >0.6997</td>
#       <td id="T_d13f9_row0_col6" class="data row0 col6" >0.3914</td>
#       <td id="T_d13f9_row0_col7" class="data row0 col7" >0.3964</td>
#       <td id="T_d13f9_row0_col8" class="data row0 col8" >2.7010</td>
#     </tr>
#     <tr>
#       <th id="T_d13f9_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_d13f9_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d13f9_row1_col1" class="data row1 col1" >0.6935</td>
#       <td id="T_d13f9_row1_col2" class="data row1 col2" >0.7665</td>
#       <td id="T_d13f9_row1_col3" class="data row1 col3" >0.6528</td>
#       <td id="T_d13f9_row1_col4" class="data row1 col4" >0.7559</td>
#       <td id="T_d13f9_row1_col5" class="data row1 col5" >0.7005</td>
#       <td id="T_d13f9_row1_col6" class="data row1 col6" >0.3900</td>
#       <td id="T_d13f9_row1_col7" class="data row1 col7" >0.3945</td>
#       <td id="T_d13f9_row1_col8" class="data row1 col8" >0.2100</td>
#     </tr>
#     <tr>
#       <th id="T_d13f9_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_d13f9_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_d13f9_row2_col1" class="data row2 col1" >0.6905</td>
#       <td id="T_d13f9_row2_col2" class="data row2 col2" >0.7592</td>
#       <td id="T_d13f9_row2_col3" class="data row2 col3" >0.6567</td>
#       <td id="T_d13f9_row2_col4" class="data row2 col4" >0.7490</td>
#       <td id="T_d13f9_row2_col5" class="data row2 col5" >0.6997</td>
#       <td id="T_d13f9_row2_col6" class="data row2 col6" >0.3833</td>
#       <td id="T_d13f9_row2_col7" class="data row2 col7" >0.3869</td>
#       <td id="T_d13f9_row2_col8" class="data row2 col8" >0.8180</td>
#     </tr>
#     <tr>
#       <th id="T_d13f9_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_d13f9_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_d13f9_row3_col1" class="data row3 col1" >0.6891</td>
#       <td id="T_d13f9_row3_col2" class="data row3 col2" >0.7586</td>
#       <td id="T_d13f9_row3_col3" class="data row3 col3" >0.6830</td>
#       <td id="T_d13f9_row3_col4" class="data row3 col4" >0.7328</td>
#       <td id="T_d13f9_row3_col5" class="data row3 col5" >0.7070</td>
#       <td id="T_d13f9_row3_col6" class="data row3 col6" >0.3767</td>
#       <td id="T_d13f9_row3_col7" class="data row3 col7" >0.3778</td>
#       <td id="T_d13f9_row3_col8" class="data row3 col8" >1.5690</td>
#     </tr>
#     <tr>
#       <th id="T_d13f9_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_d13f9_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_d13f9_row4_col1" class="data row4 col1" >0.6878</td>
#       <td id="T_d13f9_row4_col2" class="data row4 col2" >0.7557</td>
#       <td id="T_d13f9_row4_col3" class="data row4 col3" >0.6594</td>
#       <td id="T_d13f9_row4_col4" class="data row4 col4" >0.7432</td>
#       <td id="T_d13f9_row4_col5" class="data row4 col5" >0.6987</td>
#       <td id="T_d13f9_row4_col6" class="data row4 col6" >0.3771</td>
#       <td id="T_d13f9_row4_col7" class="data row4 col7" >0.3800</td>
#       <td id="T_d13f9_row4_col8" class="data row4 col8" >1.2450</td>
#     </tr>
#     <tr>
#       <th id="T_d13f9_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_d13f9_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_d13f9_row5_col1" class="data row5 col1" >0.6875</td>
#       <td id="T_d13f9_row5_col2" class="data row5 col2" >0.7576</td>
#       <td id="T_d13f9_row5_col3" class="data row5 col3" >0.7121</td>
#       <td id="T_d13f9_row5_col4" class="data row5 col4" >0.7170</td>
#       <td id="T_d13f9_row5_col5" class="data row5 col5" >0.7145</td>
#       <td id="T_d13f9_row5_col6" class="data row5 col6" >0.3693</td>
#       <td id="T_d13f9_row5_col7" class="data row5 col7" >0.3694</td>
#       <td id="T_d13f9_row5_col8" class="data row5 col8" >0.5270</td>
#     </tr>
#     <tr>
#       <th id="T_d13f9_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_d13f9_row6_col0" class="data row6 col0" >Ridge Classifier</td>
#       <td id="T_d13f9_row6_col1" class="data row6 col1" >0.6872</td>
#       <td id="T_d13f9_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_d13f9_ro
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=4235, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
